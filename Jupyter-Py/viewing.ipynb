# %%
import pandas as pd

# %%
# pd.read_excel('../ViewingActivity3.xlsx', index_col=0)
# sheet1 = pd.read_excel(view_file, sheet_name= 'in', index_col= 0)
view_file = ('../ViewingActivity3.xlsx')
newData = pd.read_excel(view_file, index_col= 0)

# %%
newData

# %%
newData.tail()
# Out:
#                       Start Time  Duration Attributes  \
# Profile Name
# Hima         2019-11-03 18:52:05  00:04:16        NaN
# Hima         2019-11-03 18:35:37  00:10:38        NaN
# Hima         2019-11-03 14:47:49  01:24:37        NaN
# Hima         2019-11-03 03:32:07  00:30:45        NaN
# Hima         2019-11-03 00:17:56  02:12:55        NaN
#
#                                                           Title  \
# Profile Name
# Hima          The Kominsky Method: Season 1: Chapter 1. An A...
# Hima                                          In the Tall Grass
# Hima                                          In the Tall Grass
# Hima          Inside the Mind of a Serial Killer: Season 2: ...
# Hima                                                   The King
#
#              Supplemental Video Type                 Device Type  Bookmark  \
# Profile Name
# Hima                             NaN  Apple iPhone 8 Plus (CDMA)  00:04:16
# ...

# %%
newData.head()
# Out:
#                       Start Time  Duration                       Attributes  \
# Profile Name
# Emily        2022-07-27 21:52:02  00:31:24                              NaN
# Emily        2022-07-27 21:29:15  00:18:33                              NaN
# Emily        2022-07-27 20:52:16  00:00:23  Autoplayed: user action: None;
# Emily        2022-07-27 17:57:41  00:10:57                              NaN
# Emily        2022-07-27 16:11:38  00:09:21                              NaN
#
#                                                           Title  \
# Profile Name
# Emily         Virgin River: Season 4: Otherwise Engaged (Epi...
# Emily         Virgin River: Season 4: All's Faire... (Episod...
# Emily             Season 1 Trailer: The Way of the Househusband
# Emily         Virgin River: Season 4: All's Faire... (Episod...
# Emily         Virgin River: Season 4: All's Faire... (Episod...
#
#              Supplemental Video Type              Device Type  Bookmark  \
# Profile Name
# ...

# %%
sorted_col = newData.sort_values(['Duration'], ascending=False)

# %%
sorted_col['Duration'].head(10)
# Out:
# Profile Name
# Hima     02:21:20
# Hima     02:12:55
# Hima     02:08:10
# Emily    01:57:35
# Hima     01:56:30
# Hima     01:53:31
# Emily    01:52:23
# Emily    01:45:57
# Hima     01:41:43
# Hima     01:41:17
# Name: Duration, dtype: object

# %%
newData.describe
# Out:
# <bound method NDFrame.describe of                       Start Time  Duration                       Attributes  \
# Profile Name
# Emily        2022-07-27 21:52:02  00:31:24                              NaN
# Emily        2022-07-27 21:29:15  00:18:33                              NaN
# Emily        2022-07-27 20:52:16  00:00:23  Autoplayed: user action: None;
# Emily        2022-07-27 17:57:41  00:10:57                              NaN
# Emily        2022-07-27 16:11:38  00:09:21                              NaN
# ...                          ...       ...                              ...
# Hima         2019-11-03 18:52:05  00:04:16                              NaN
# Hima         2019-11-03 18:35:37  00:10:38                              NaN
# Hima         2019-11-03 14:47:49  01:24:37                              NaN
# Hima         2019-11-03 03:32:07  00:30:45                              NaN
# Hima         2019-11-03 00:17:56  02:12:55                              NaN
#
# ...
